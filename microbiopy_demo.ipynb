# %% [markdown]
# # Microbiopy Demo

# %% [markdown]
# ## Install Microbiopy To See The Results as Follows:

# %%
import log_transform_pca as ltp

# %% [markdown]
# ## Plotting PCA Results

# %%
ltp.implement_generate_pca()
